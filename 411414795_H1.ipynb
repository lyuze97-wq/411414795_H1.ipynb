# %% [markdown]
# <a href="https://colab.research.google.com/github/lyuze97-wq/411414795_H1.ipynb/blob/main/411414795_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
X=50000*(1+0.015)**5
print(X)
# Out:
# 53864.20019421873

# %%
x=int(input("請輸入目前金幣數量: "))
y=int(input("請輸入目前金幣數量: "))
z=x+y
print(f"任務完成！你現在有{z}枚金幣 ")
# Out:
# 請輸入目前金幣數量: 250
# 請輸入目前金幣數量: 500
# 任務完成！你現在有750枚金幣
